# %% [markdown]
# Capture 10 seconds of video from a camera and writes it to an AVI file.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import cv2

# %%
cameraCapture = cv2.VideoCapture(0)
cameraCapture
# Out:
# < cv2.VideoCapture 000001B1CB79E7D0>

# %%
#cameraCapture = cv2.VideoCapture(0, cv2.CAP_MSMF)
#cameraCapture

# %%
# Check if cameraCapture is opened correctly
cameraCapture.isOpened()
# Out:
# True

# %%
fps = 30
size = (int(cameraCapture.get(cv2.CAP_PROP_FRAME_WIDTH)),
        int(cameraCapture.get(cv2.CAP_PROP_FRAME_HEIGHT)))
size
# Out:
# (640, 480)

# %%
videoWriter = cv2.VideoWriter(
    'CaptureCameraFrames.mp4', cv2.VideoWriter_fourcc('H','2','6','4'),
    fps, size)

# %%
success, frame = cameraCapture.read()
#success
#frame
frame.ndim
frame.shape
# Out:
# 3
# (480, 640, 3)

# %%
numFramesRemaining = 10 * fps - 1 # 10 seconds of frames
while success and numFramesRemaining > 0:
    videoWriter.write(frame)
    success, frame = cameraCapture.read()
    numFramesRemaining -= 1
